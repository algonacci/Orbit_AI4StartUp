# %% [markdown]
# <a href="https://colab.research.google.com/github/algonacci/Orbit_AI4StartUp/blob/main/Belajar_Anime_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install git+https://github.com/ariaghora/ezpznet
# Out:
# ...
#   Cloning https://github.com/ariaghora/ezpznet to /tmp/pip-req-build-sn0bjj68
#   Running command git clone -q https://github.com/ariaghora/ezpznet /tmp/pip-req-build-sn0bjj68
# ...
#   Created wheel for ezpznet: filename=ezpznet-0.1.0-py3-none-any.whl size=7543 sha256=533ed64f14d374287354a94d9b0dfc28c8d8c9c758400052554acc54ef385796
#   Stored in directory: /tmp/pip-ephem-wheel-cache-k14qc91a/wheels/3f/9f/84/ecb3dfe9d69e6b5bed7771fee5a2344996f1cdd36981225c8b
# Successfully built ezpznet
# ...

# %%
from ezpznet.sketchgan import SketchGAN, load_image
image_path = "/content/anime.jpg"
image_path2 = "/content/anime_2.jpg"
image = load_image(image_path2)
net = SketchGAN()
pred = net.predict(image)
plt.imshow(pred.squeeze(), cmap="gray")

# %%
from ezpznet.animegan import AnimeGAN, load_image

elon_musk = "/content/elon_musk.jpg"

net = AnimeGAN(style="facepaint")
image = load_image(elon_musk)
pred = net.predict(image)
plt.imshow(pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ezpznet/weights/face_paint_512_v2_0.pt: 100%|██████████| 8.20M/8.20M [00:00<00:00, 36.0MiB/s]

# %%
from ezpznet.animegan import AnimeGAN, load_image

japan_park = "/content/japan_park.jpg"

net = AnimeGAN(style="hayao")
image = load_image(japan_park)
pred = net.predict(image)
plt.imshow(pred)
# Out:
# /usr/local/lib/python3.7/dist-packages/ezpznet/weights/hayao.pt: 100%|██████████| 8.20M/8.20M [00:00<00:00, 31.1MiB/s]
